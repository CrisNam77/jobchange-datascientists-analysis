# %%
import numpy as np
import sys
sys.path.append("..")

from src.data_processing import preprocess_train, preprocess_test

# %%
TRAIN_PATH = "../data/raw/aug_train.csv"
TEST_PATH = "../data/raw/aug_test.csv"

# %% [markdown]
# Tiền xử lý train

# %%
X_train, y_train, meta = preprocess_train(
    TRAIN_PATH,
    save_csv_path="../data/processed/processed_train.csv"
)


print("Train X shape:", X_train.shape)
print("Train y shape:", y_train.shape)
# Out:
# Train X shape: (19158, 12)
# Train y shape: (19158,)

# %% [markdown]
# Tiền xử lý test

# %%
X_test, test_ids = preprocess_test(
    TEST_PATH,
    meta,
    save_csv_path="../data/processed/processed_test.csv"
)

print("Test X shape:", X_test.shape)
print("Số enrollee_id:", len(test_ids))
# Out:
# Test X shape: (2129, 12)
# Số enrollee_id: 2129
